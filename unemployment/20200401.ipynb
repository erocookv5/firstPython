# %%
import pandas as pd
from matplotlib import pyplot as plt

# taken from here: https://data.europa.eu/euodp/en/data/dataset/jrc-10113-rio_unemp_edlevel
data = pd.read_csv("/home/matteo/mypython/RIO_UNEMP_EDLEVEL-data.csv")
metadata = pd.read_csv("/home/matteo/mypython/RIO_UNEMP_EDLEVEL-meta.csv")
dataset = data[["GEO_DESC", "TIME_PERIOD", "SEX", "SEX_DESC", "AGE", "OBS_STATUS", "OBS_STATUS_DESC", "OBS_VALUE", "ISCED11"]]
dt = dataset[dataset.OBS_STATUS.notnull()]
dt
# Out:
#       GEO_DESC  TIME_PERIOD SEX SEX_DESC     AGE OBS_STATUS  \
# 48     Estonia         2000   F  Females  Y15-74          b
# 53     Estonia         2005   F  Females  Y15-74          b
# 104   Bulgaria         2003   F  Females  Y15-74          b
# 106   Bulgaria         2005   F  Females  Y15-74          b
# 107   Bulgaria         2006   F  Females  Y15-74          b
# ...        ...          ...  ..      ...     ...        ...
# 6547    Sweden         2018   M    Males  Y15-74          b
# 6550    Sweden         2018   F  Females  Y15-74          b
# 6551    Sweden         2018   F  Females  Y15-74          b
# 6552    Sweden         2018   F  Females  Y15-74          b
# 6553    Sweden         2018   F  Females  Y15-74          b
#
#            OBS_STATUS_DESC  OBS_VALUE ISCED11
# 48    break in time series       14.7   ED3_4
# 53    break in time series        8.6   ED3_4
# 104   break in time series        7.4   ED5-8
# 106   break in time series        4.2   ED5-8
# ...

# %%
# ED3: UPPER SECONDARY EDUCATION
# ED4: POST-SECONDARY NON-TERTIARY EDUCATION

# Unemployment % for ED3-4 educated population: Sweden

#ED3_4 Male case
swedenM = dt[dt.GEO_DESC == "Sweden"]
swedenM = swedenM[dt.SEX == "M"]
swedenM = swedenM[dt.OBS_STATUS != "bu"]
swedenM = swedenM[dt.OBS_STATUS != "u"]
swedenM = swedenM.sort_values(by = ["TIME_PERIOD"])
swedenM = swedenM[dt.ISCED11 == "ED3_4"] 
swedenM
# Out:
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
#      GEO_DESC  TIME_PERIOD SEX SEX_DESC     AGE OBS_STATUS  \
# 1546   Sweden         2001   M    Males  Y15-74          b
# 1550   Sweden         2005   M    Males  Y15-74          b
# 1551   Sweden         2006   M    Males  Y15-74          b
# ...

# %%
xm = swedenM.TIME_PERIOD
ym = swedenM.OBS_VALUE
plt.figure()
plt.plot(xm, ym)
plt.title("ED3_4")
plt.xlabel("years")
plt.ylabel("% unemployed males (15-74 aged)")
plt.show()

# %%
#ED3_4 Female case
swedenF = dt[dt.GEO_DESC == "Sweden"]
swedenF = swedenF[dt.SEX == "F"]
swedenF = swedenF[dt.OBS_STATUS != "bu"]
swedenF = swedenF[dt.OBS_STATUS != "u"]
swedenF = swedenF.sort_values(by = ["TIME_PERIOD"])
swedenF = swedenF[dt.ISCED11 == "ED3_4"] 
swedenF
# Out:
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#      GEO_DESC  TIME_PERIOD SEX SEX_DESC     AGE OBS_STATUS  \
# 387    Sweden         2001   F  Females  Y15-74          b
# 391    Sweden         2005   F  Females  Y15-74          b
# ...

# %%
xf = sweden.TIME_PERIOD
yf = sweden.OBS_VALUE
plt.figure()
plt.plot(xf, yf)
plt.title("ED3_4")
plt.xlabel("years")
plt.ylabel("% unemployed males (15-74 aged)")
plt.show()

# %%
# T Total case
swedenT = dt[dt.GEO_DESC == "Sweden"]
swedenT = swedenT[dt.SEX == "T"]
swedenT = swedenT[dt.OBS_STATUS != "bu"]
swedenT = swedenT[dt.OBS_STATUS != "u"]
swedenT = swedenT.sort_values(by = ["TIME_PERIOD"])
swedenT = swedenT[dt.ISCED11 == "ED3_4"] 
swedenT
# Out:
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# /home/matteo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#      GEO_DESC  TIME_PERIOD SEX SEX_DESC     AGE OBS_STATUS  \
# 4107   Sweden         2001   T    Total  Y15-74          b
# 4111   Sweden         2005   T    Total  Y15-74          b
# ...

# %%
xt = sweden.TIME_PERIOD
yt = sweden.OBS_VALUE
plt.figure()
plt.plot(xt, yt)
plt.title("ED3_4")
plt.xlabel("years")
plt.ylabel("% unemployed (15-74 aged)")
plt.show()

# %%
# As you can see, T and F cases are identical. Let's skip T and let's compare M and F cases at once.
plt.figure()
plt.plot(xm, ym, "c:H")
plt.plot(xf, yf, "g-D")
plt.title("ED3_4")
plt.xlabel("years")
plt.ylabel("% unemployed (15-74 aged)")
plt.legend(["male", "female"])
plt.show()
